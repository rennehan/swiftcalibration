# %%
import os
import sys
import yt
import caesar
import unyt
import argparse
import numpy as np

import gen_sim_data as gen

from velociraptor.observations.objects import ObservationalData
from astropy.cosmology import FlatLambdaCDM
import astropy.units as u

SNAP = '/scratch/b/babul/stlock/snapshots/HyenasC/L0/halo_3224_finished_runs/BAL_variations/run01/snapshot_151.hdf5'
ds = yt.load(SNAP)
# Out:
# yt : [INFO     ] 2025-07-06 02:59:34,946 Calculating time from 1.000e+00 to be 4.375e+17 seconds
# yt : [INFO     ] 2025-07-06 02:59:34,950 Assuming length units are in kpc/h (comoving)
# yt : [INFO     ] 2025-07-06 02:59:35,041 Parameters: current_time              = 4.3748565942961094e+17 s
# yt : [INFO     ] 2025-07-06 02:59:35,041 Parameters: domain_dimensions         = [1 1 1]
# yt : [INFO     ] 2025-07-06 02:59:35,042 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-07-06 02:59:35,043 Parameters: domain_right_edge         = [200000. 200000. 200000.]
# yt : [INFO     ] 2025-07-06 02:59:35,043 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2025-07-06 02:59:35,043 Parameters: current_redshift          = 4.440892098500626e-16
# yt : [INFO     ] 2025-07-06 02:59:35,044 Parameters: omega_lambda              = 0.7
# yt : [INFO     ] 2025-07-06 02:59:35,044 Parameters: omega_matter              = 0.3
# yt : [INFO     ] 2025-07-06 02:59:35,044 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2025-07-06 02:59:35,045 Parameters: hubble_constant           = 0.68

# %%
ad = ds.all_data()
print(ad["PartType0", "InternalEnergy"].units)
# Out:
# code_specific_energy
